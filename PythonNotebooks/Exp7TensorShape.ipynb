# %%
import sys
sys.path.append('../')
from PythonFiles.data import *
import tensorflow as tf
# Out:
# WARNING:tensorflow:From ..\PythonFiles\data.py:8: The name tf.enable_eager_execution is deprecated. Please use tf.compat.v1.enable_eager_execution instead.

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
tensordata1 = get_dataset(configs_add_closed_hh)
inputs,outputs = get_input_output_tensors(tensordata1)
# Out:
# WARNING:tensorflow:From ..\PythonFiles\data.py:54: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Reading examples from TFDS: groove/2bar-midionly
# WARNING:tensorflow:Entity <function get_dataset.<locals>.<lambda> at 0x00000224E76D28B8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: expected exactly one node node, found []
# WARNING:tensorflow:Entity <function get_dataset.<locals>.<lambda> at 0x00000224E76D28B8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: expected exactly one node node, found []
# ...

# %%
# print(inputs)
# print(outputs)
print(inputs==outputs)
# Out:
# False
